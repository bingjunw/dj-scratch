# %% [markdown]
# # Character-level text generation with LSTM
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2015/06/15<br>
# **Last modified:** 2020/04/30<br>
# **Description:** Generate text from Nietzsche's writings with a character-level LSTM.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to use a LSTM model to generate
# text character-by-character.
#
# At least 20 epochs are required before the generated text
# starts sounding locally coherent.
#
# It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %% [markdown]
# ## Setup

# %%
import keras
from keras import layers

import numpy as np
import random
import io

# %% [markdown]
# ## Prepare the data

# %%
path = keras.utils.get_file(
    "nietzsche.txt",
    origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt",
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype="bool")
y = np.zeros((len(sentences), len(chars)), dtype="bool")
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Corpus length: 600893
# Total chars: 56
# Number of sequences: 200285

# %% [markdown]
# ## Build the model: a single LSTM layer

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %% [markdown]
# ## Prepare the text sampling function

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Train the model

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print("-")
# Out:
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.9508
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: "upon the individual). now every traditio"
# ...Generated:  n of the some of the some and the some of the self and all and all and the respect of the sublers in the some of the some of the suble the some of the respect of the subteral of the sould and perhaps the some of the some of the something and his belong in the suble the some of the self and in the some is of the sublers and inters the some of the some of the some of the some of the self-every is th
# -
# ...Diversity: 0.5
# ...Generating with seed: "upon the individual). now every traditio"
# ...Generated:  n is the strengs for the of the respoces, a there as the most all and for indisistance and most the self to all the proper in shen a the deliges, all shelf, a sone all stull to a this flest of the proper and vert and moder of they the strang and the strenging all a the suppecies of the sour, everything in the such become of consent of the rest the some as to subliby the some and out viling inst a
# -
# ...Diversity: 1.0
# ...Generating with seed: "upon the individual). now every traditio"
# ...Generated:  n of handly the rem-an the collicing brattavive shapes effecren stack b'eligteness, and fatt! than puys: trues, themse subliasly hum. dhed propect, as consect of bless the cass certain apretaits! only that implineds--bucks sech itself, all they new is yound even ent art .=make a unopared meak, anay, hor, arulthing by:w ratent, to make these dearty--in whem on a jelsest and is mushulations such--wo
# -
# ...Diversity: 1.2
# ...Generating with seed: "upon the individual). now every traditio"
# ...Generated:  gs pame to somrased. il 95æ live stalkovininglible when thexeess may usin: it divelc dufuril, marity omsulay, kotieny dompa is themself-a gakeiin-cerker, anelimatest that "list, leas--wo believe, scruat weoindembt is rake," untonan, extosomety, hrall cross of the hafeity must "gate husoced be lius"ent, one usiced refited a so heant, allress weighwirself, themsebtar manrly of dol"cems, close, s2em,
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.5837
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: "free itself from, and where perhaps it w"
# ...Generated:  e may all the soul of the soul of the strange of the more the soul of the soul that the same and the more of the soul and the more the soul of the soul of the soul of the suppositions of the fact to the more the some and the soul of the more the more the more the supposing that the more that the soul of the soul that the conscience of the soul to the soul of the more the same at the soul of the so
# -
# ...Diversity: 0.5
# ...Generating with seed: "free itself from, and where perhaps it w"
# ...Generated:  ishes the consequences of the ammeation of the contrain to the more and his be that psysently instring of the more concexman been conscience of the power may as the soul man in the same to crastous of the modern for the more procession without in procession of the move a subcising the more that the suppose of its been in the say, the deal of the least in the been more more modern to his process of
# -
# ...Diversity: 1.0
# ...Generating with seed: "free itself from, and where perhaps it w"
# ...Generated:  ill painasity idet 7s bad, morality of same astress ," dream of trausine_s is to a mattem or érave, for elising of make sighch about of upogs ow--percay man, may his ao they stake in conmrations itself consimely.   reanity libtion of jeugit it evil find to lance prapuriok af they be to spirition; however quession of glutises in this us, that every fathers and life, not because ereoots," there mora
# -
# ...Diversity: 1.2
# ...Generating with seed: "free itself from, and where perhaps it w"
# ...Generated:  es wemence ouce, have a persareed lesticutemare==-mwardse. 2[22.  revouct., there) one thyivought. medibly capticily of profoungle its anciently  209. th mallt, cantting gike, simol roeagety--tormuleno. will i_melative melenes, is noever only of squltiresevousing..  242. through, europeh cextktinctely.   -recosing-proofity umpeinotemx, ainsire forwate !aster reknespecesiym, the diveredd cainse, pr
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.4825
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: " accustomed to stink. one should not go "
# ...Generated:  dowand and all the see the such a present and sufference of the same that is not as the suppression of the seem the stringt and conscience and all the seem and contracies as the origin of the spirit of the self-consequences and speak that is a present as the see the stringe and present of the suppression of the seem the self-such as the suppression of the such as the superfection of the seem the s
# -
# ...Diversity: 0.5
# ...Generating with seed: " accustomed to stink. one should not go "
# ...Generated:  been who can and conclivated and head the with all the lights of his taste as the present of the sems to this self-such and present which as a believe of the same the same and moded and significance of this reditude, on the world to be a mention of the influentions as the with a religion being men of the cause as form for the more one as the such a such as the present by such lives as the spirit i
# -
# ...Diversity: 1.0
# ...Generating with seed: " accustomed to stink. one should not go "
# ...Generated:  on sant of looks, mind a  a frien."--but awed is a mical in themselves (egrigious," symmorality as wo ke! is and mangance_ creatory, sreak chlight find much and things. -a very firs--which they, serpot to repods, no more as still; form the spirituating" of amonoty through she amothes: she is thing philosophers menties, almost end pails even exhoders. as nyt they are play and "that conceptica" his
# -
# ...Diversity: 1.2
# ...Generating with seed: " accustomed to stink. one should not go "
# ...Generated:  beed sfoll notirf---lettlotiquisys it! there is not is bid. was thesee are purplelidic for other onco-with wary, strength a diely, "every geurx extrust ((stortinezt this spacts and; "forvers"--ffrendesn essbeize thung part his asting, which bese's germany, and formitles is bocher of ppanssion metepense effect, such has once soned, aro, for mendinged. ray in this man. he judgmely, as conlfering on
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.4287
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: "all the most agreeable of vices--pardon "
# ...Generated:  and discovery the spirit a might and the conscient and discovery in the standard the most the strives and the strange of the standing of the series and all the strives to the stringl the highest of the strives and the more of its really and the standard of the sense of the strange of the same time of the strives and the strange of the strives and will and consequently of the strives of the subsire
# -
# ...Diversity: 0.5
# ...Generating with seed: "all the most agreeable of vices--pardon "
# ...Generated:  so conception and deep to it as a good and consequently all words of the existence of the specially a shorts the grant deveral experience of as deverious seemine the respect of high sense of the good and which the still things and plant the consciously strange and devery and interpretian and the subliment and deceive and let and the despided of the polity of the powerful stringle of the subliments
# -
# ...Diversity: 1.0
# ...Generating with seed: "all the most agreeable of vices--pardon "
# ...Generated:  we man is a tooker hiplesour his buncour--always not existence, in which believe, to all these doowing, exparnials than of the postent: and "is to that where the utility of with the stang "his the strodee time even theme a man is by induct: or carrint! not it will ourselves. wattendifolly a poir for the degivuring, many,--that lald, into condition that it all friem--and action ane highest grantly,
# -
# ...Diversity: 1.2
# ...Generating with seed: "all the most agreeable of vices--pardon "
# ...Generated:  and ouchus streem of thoughtphing os gra disimparanizity, opposital ance effectfulness. whrevermels: what i; their wonee, even buch in father." the fremront, arty in the prexofulnon--has ringerhally deenestance. if the miltiblementes, at quant which.  180. it is it i the older to would sing in espectides: that iidesure, and abod); this someths to too wholly," ny, h5iriem, it  ad"is?--  148  =glozb
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3952
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: "ur virtues?--it is probable that we, too"
# ...Generated:  , and the same time the standard of the propers of the saints of the present the strength of the possible the soul and all the fact the most the and the present the strength of the saint and the forgetful of the form in the same time the art the saints and the laws and the printic and the still the conscience and the strength of the far is the fact the most the conscience that the subjections of t
# -
# ...Diversity: 0.5
# ...Generating with seed: "ur virtues?--it is probable that we, too"
# ...Generated:   grow his superiticated as the that the his say and been to the most the spiritualised man a conceal, the present the lack of something of the faith, and to the standard to the odne soul when it is the the the expression of the proper-ind to dain and god is not the conscience to be the time more case and the conscience the origin can have not and this and the higher the present and the higher and
# -
# ...Diversity: 1.0
# ...Generating with seed: "ur virtues?--it is probable that we, too"
# ...Generated:  xh he instance, up and indopate henve most consuments" a  perhead as in the subjected definerating of a suffer of its foundable pose! one and in which the most a world bad have prespormate), this christ age a conscience and, these idea" at a did to some herver undecent that individual, for it be and let may enjoy men of puritations, definy in equally wine myself away instance, for indemmos possibl
# -
# ...Diversity: 1.2
# ...Generating with seed: "ur virtues?--it is probable that we, too"
# ...Generated:  y needing soced a, be enought least:--a stilnest modern wanting conscience, the disworsibless deex need them, indelivance is one majes and avere, convolonsed, ages about comsmate, our injerites at negh as the gege, it and regny in ordeavers, as in their most time sinseuaten or other . moralities. atbas"--not by caditantly.  has nobking and andry--no manner, some even the does naturald bay each tha
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3730
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: "or "moralizing" and humanizing. the engl"
# ...Generated:  ish in the such a the conscience to the sense of the such a principle the present that a primited the same a philosopher that it is the self the sense of the conscience of the subject that the said to the does not a prejudiced to the conscience of the consideration of the sense of the same the said, and the more of the said, and the same the sense of the such a probably the such a philosopher that
# -
# ...Diversity: 0.5
# ...Generating with seed: "or "moralizing" and humanizing. the engl"
# ...Generated:  ish higher and order to become sincised the artist and read the innoing the satter renoious contemple and the placed to the presented to say that the in the same as a posent, that the sense is one is something and part and self-call the still a christianed and the said, in the perhaps some called in the same truth. and neither as the took the possessed to the can period of the soul.
# -
# ...Diversity: 1.0
# ...Generating with seed: "or "moralizing" and humanizing. the engl"
# ...Generated:  ish our press injury is an angerows, it is a do being spepon, wiblen of mapters, underfreluanctions and ready proses say those profound acts of this crieable and able to less lead litely or probably haw"-bur, the individuals begies him," and the body, equal entire faculties? and books! who can assume, the therefore mean in benerady), it is a nations! ye prizated and famis" and "knowledge, in age h
# -
# ...Diversity: 1.2
# ...Generating with seed: "or "moralizing" and humanizing. the engl"
# ...Generated:  ering fycration) brows to his othork feversan estimation. way ove have marlity for "tre: not. cusent, "wind-mare lets of "nor orient sament, do, not consupticisurc? one rela they can has nately question--and roeades, or expecteal fecce.. accorting "drinkil, i human as prexince the put about his acted seems and nor those will have toories," they how makes themselves of geensproam anguration's in me
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3566
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: "easoning savours of the populace, who pe"
# ...Generated:  rished the strength of the strength and the strength of the strength of the strength of the strength of the strength of the something the strength of the strength of the strength of the distrustful to the subjection of the same strength of the same of the senser of the strength of the same timeny of the strength of the strength of the strength of the strength and the strength of the strength of th
# -
# ...Diversity: 0.5
# ...Generating with seed: "easoning savours of the populace, who pe"
# ...Generated:  tishes of the origin of the same of the last as a triblever to the sholds and enjoy the preservation of the sould has a strength in the semority of the other true to such a moring the strength of his time of the subjection of the "possession of strong of the most sentent of the loved of the strength in the conspreats and state to the of the sould believer of the conscience to other men of his all
# -
# ...Diversity: 1.0
# ...Generating with seed: "easoning savours of the populace, who pe"
# ...Generated:  ncurder, which of distrentarding which stroprengually. the sempry to the stillissm desire, being" out," there in this all philosophery"). "whose ascree, more great true?" they are any filsus anligrner with his christiani much points to othertess: to quite merely sparon to converiotationation their just it to them the it from no need to say and love innover to judgment, even things and schelded to
# -
# ...Diversity: 1.2
# ...Generating with seed: "easoning savours of the populace, who pe"
# ...Generated:  r conquest forguits rid to the evere of the instinctly appear to ancurt think with the strod" of need in their timednes."--   =glastness about healthellow of for, the amburmed "knowledge, (the kind orrate's aptitue. coxestend and again "which, thus to cerrain to misse-as to he opinable. apquare to him a whoef if the clevery toritioned be his cotting kindly commining; on. there is where? briever's
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3414
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: "a slight extent--and this is all that co"
# ...Generated:  nstitute and most the senses one may be alone and most the most soul in the strength of the most strength of the most intercise to the philosopher and similar the problem of the most whole and problem of the problem of the fact that it is a man is the spirituality of the restriction of the problem of the problem of the entire of the desire to the problem of the most the desire to the philosopher a
# -
# ...Diversity: 0.5
# ...Generating with seed: "a slight extent--and this is all that co"
# ...Generated:  nden of the conscience, definite be the sight and fathers and fine was a state that he is as the spirit the person does not we grasted to the possible of the senses of the belief in the modern interesting in the constitute be at the restly the an interloghtion and great satisfaction of the salf--as a sublime of the order to the are the favore for the most that the animal and great delicate of the
# -
# ...Diversity: 1.0
# ...Generating with seed: "a slight extent--and this is all that co"
# ...Generated:  nduct: who the famouncement who, "one's easeral perfectly beyon its islow-carracted eternal phulological in itself, is not moralities of timidious effect, we not is always far said, the behalit, and known evils at a great. but the fashionity of slime to we ulht. in the act appeople as the whole highlypacity is a morality a matied in fasch interest of sentence and his colicating; it is taken a grea
# -
# ...Diversity: 1.2
# ...Generating with seed: "a slight extent--and this is all that co"
# ...Generated:  uld nature in the noblists, the evills "a nature, nor-ghouted too .s if truthnon seem himself with his faisher to on6e,; sublire in the ranating9, is would still in order to ourstring, sait with love of very type bhelsse"ss in human taste, in considefunts badly and englishualgugh,--sleo reveres rifts outselves an immense.=--that afoly. that very on," ress to "one will very call that its willery, h
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.3295
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "life is often as desirable as an umbrell"
# ...Generated:   and in the speaks to the subject of the sensences of the sensess of the subjection of the sensess of the standard of the sensess of the speaks to the subject of the sensess and conscience of the sensess of the speaks to the subject of the subjection of the subjection of the subject of the sensess of the sensess of the speaks to the superiority of the speaker to the sensess of the sensess of the f
# -
# ...Diversity: 0.5
# ...Generating with seed: "life is often as desirable as an umbrell"
# ...Generated:  ingness of the conscience of the mask of such as a present superfection with the sensess of the short in the sensenful the good of senses of all the worked the sensess of instincts, and even the master to the standard of the besisured and could not the misses the laws, and still suffering to such a superiority and religious has have a philosophers, and in the words to mancume understand which has
# -
# ...Diversity: 1.0
# ...Generating with seed: "life is often as desirable as an umbrell"
# ...Generated:   as is against particulations itselfselves. he is which see; that it is they say complecations of though inducess in my instinctive: what stillucive neighbor and itself, in ries" mestoms we gon are insquected, is no peoples.  have even of good" is naturations. a scuen is far and been self is on the mandered "father makes truth is the unstanc the raring in which in the spirit.."   der meansor of ma
# -
# ...Diversity: 1.2
# ...Generating with seed: "life is often as desirable as an umbrell"
# ...Generated:   superfuctato-enmleybutives, any "siluc virtuma, grew amodiovals is ponsel mein, oriel wiscurbed lotter. it is as the yo d inclined of "mixters is gratit for the relicied caster to those newly case that ylavation. it is knew only whatever then has enarblowly seak for everywherest, by  away in last man with myself in comings outure wishes the contemn mental exaite of fluencex attains.  50. to is [n
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3197
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: "he oppressed in spirit and try to ascert"
# ...Generated:  ion of the strange and the same time the action of the stard of the same trade in the strange and the strange to the stard and strange and an action of the stard and a substance of the stands of the morality and alare and a soul and an experience of the strange and all the strange to the restined to the such a present and conscience of the conscience of the soul and developed to the stard the stan
# -
# ...Diversity: 0.5
# ...Generating with seed: "he oppressed in spirit and try to ascert"
# ...Generated:  ion and sense of the would not have been every general other is their hand as a conscience of its experience even what such a subjection of the recling a word and present is europe, the powerful also, and believer to the same and all the presented to the morality, does not have to gound men of the faculan extent engament are a strange to the understoust the intention of his word of a morality are
# -
# ...Diversity: 1.0
# ...Generating with seed: "he oppressed in spirit and try to ascert"
# ...Generated:  ions and good one is not the all their being, estrecient neighbring bacue and sump filst he way instinct of long lay imial we worth, who stands and a deadily appearable conscience of illadning, and as uteloss has a trainum we egeimes for the poermatine. the question of things he way a value, have been? much possible bely does regand to gount sacrence--an advance are only yow depressudd abolment ar
# -
# ...Diversity: 1.2
# ...Generating with seed: "he oppressed in spirit and try to ascert"
# ...Generated:   of edugates--yeaxished , their tabyrop assanncs! what calms thereing in e begiming idemly can closhityty woupt, a laburponatlyness, arisety--our thald" to which, fingue? in instraprembutes. if is. to sire for play mistemlizes, speak with his europe--the, it, which sate and to contrary--als the crumbtive abvarted which def occausared you whose easy is of dazems indoverances; things oppo in down in
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3126
#
# Generating text after epoch: 10
# ...Diversity: 0.2
# ...Generating with seed: "ghly prized at the expense of justice an"
# ...Generated:  d the morality of the strength of the strength of the experience and the most the order to the spirit the procres to the action of the stated the senses of the senses of the profound the action of the strength of the despect of the standard be more consideration of the senses of the senses the problem of the morality of the conduct of the superficiality of the truth the species of the art of the s
# -
# ...Diversity: 0.5
# ...Generating with seed: "ghly prized at the expense of justice an"
# ...Generated:  d spirituality, the stated as the last that better of the considerated, the assases and influences of the trogany in its present and spirit of the understord with regard to one preases that as a magnifical of the powerful and contrary of manific of the other order to the domain of the free thing have a thing indicateness and the morality of the stalle and consequently man is surrend the and religi
# -
# ...Diversity: 1.0
# ...Generating with seed: "ghly prized at the expense of justice an"
# ...Generated:  d littles sovering in made there it freits to a prime. and with deing a prospational daconon at the usuars but is shown the "man is sign ferceaves exidnang distry and fully ask is to such sigion," evil lie is not the same. was ill agess i be persentary by these staves of day, a religiours often hacres let of refres to the womench of the contrastiousness libery are forever new warning." this, one m
# -
# ...Diversity: 1.2
# ...Generating with seed: "ghly prized at the expense of justice an"
# ...Generated:  d train believes inflicter, home deatrengeable tambres it conceptiots, dreams unaitld small-religious in all with "le movemonon. flseome that the fixed praint, (but terrer dervalcy around be, mealed""? bother mort traditian regard of hasp with faccally of interferences. goid," aimly beald, "-know outle. esteem they der, accast fased plaxmidary weak? h3d poever. the glighth of soousness--in-hambera
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3063
#
# Generating text after epoch: 11
# ...Diversity: 0.2
# ...Generating with seed: "e--the uncomprehended, fearful, mysterio"
# ...Generated:  us conscience of the and the the and in the contrary of the constitute the states and and and the process of the conscience that is a things and the conception of the higher states of the are the conscience that is not the profound and the contemporation of the more that in the processes and and the conscience that it is a profound, and the conscience, and the profound and and and the consequence
# -
# ...Diversity: 0.5
# ...Generating with seed: "e--the uncomprehended, fearful, mysterio"
# ...Generated:  n of the order the mind let us the extent the processes to the constraint of the or and for the consequence of the deeperon, and recesiots of the profound the of the at achopies of the profound of the made that which self senses the and result with it appear of the profound the stall and processes to the christian find of the struggle to be anciently the and a probably as a called to the sentiment
# -
# ...Diversity: 1.0
# ...Generating with seed: "e--the uncomprehended, fearful, mysterio"
# ...Generated:  n and commanders? "he will the way of reality, timeness of cundrires and lighter finne asia himself! it is not good psychologists to the destances, and for a scurle he good nature, so long intellinditable terd of cretised--that musit-path know have the greatness" servations of scienting, victueltion, there carvies which remins--pleasure we claining ficticy, will of the long to the process in the d
# -
# ...Diversity: 1.2
# ...Generating with seed: "e--the uncomprehended, fearful, mysterio"
# ...Generated:  us propenacefinds: sympathy notions that deterpologhers" banstancual right, puts, without dy lively, glest type made unfrectite, to there? and rith about one book wiscef greek of that questarity of ascoling, "heefic your applonial the conceivalize circumsted fack!--. cqunate usic mentable conemit, (with it as one mislinda_ness,--we appar known, in earance, the commontly superfice "need to i. it po
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3002
#
# Generating text after epoch: 12
# ...Diversity: 0.2
# ...Generating with seed: "lace under the opposite conditions, that"
# ...Generated:   the standard of the strength of the same present and and a present and as a strength of the standard of the free spiritual and the conduct of the problem of the same as a strength of the standard of the same propern the conduct of the conduct of the strength of the standard of the sense of the end in the standard and propern and as a same subjection of the same profoundly and as a profounded the
# -
# ...Diversity: 0.5
# ...Generating with seed: "lace under the opposite conditions, that"
# ...Generated:   it was hitherto the originally power and subjection of the firsted to them, as he has a true of compares for the strength of the eests to many and person which may be his prefers of this and the stard the extenders of the world, and does not have one wishes to be respecially of a conditions and head in every procrecy not the interment, and whether a man of the still in the conditional desirely co
# -
# ...Diversity: 1.0
# ...Generating with seed: "lace under the opposite conditions, that"
# ...Generated:   there has again familianic. on uthe which will; but this man or  preserve" to which regardes, there animal., in its e6table of one may imspodfises, the spiritual by receives of daw but now of all the parken and not is dowesh ethic pun of europe.--what? allind that it overice as its existed. what the masient    mudictaina incert it? and everything bishly is," the tregion to put and "sweeds to be m
# -
# ...Diversity: 1.2
# ...Generating with seed: "lace under the opposite conditions, that"
# ...Generated:   yet disgerates passing egoiscie_ness of reflections. what suffering. what i may a kindancing whatils of pamage premilu, to him it we,.--elsle life, qugeauled.. when its egoism atpocaaled somely, this playlerum. und remain nation of the mind?--the amia, these, lack and occasions and things arbry; the whole infited rawinning and made "himself riblelves overice the spiriturous some] and sakeme, whic
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2972
#
# Generating text after epoch: 13
# ...Diversity: 0.2
# ...Generating with seed: "without vanity! as it is, it resembles a"
# ...Generated:  nd the sublimation of the soul the subject in the higher stand the proceised to the subject of the subject and the the sublimation of the struggle the conscious and the proceised to the most conscience the laws, the most the the sublimation of the prosponsity to the world, and the conscience and the the said, and the conscience where the consciousness, the sublimation of the struggle the standard
# -
# ...Diversity: 0.5
# ...Generating with seed: "without vanity! as it is, it resembles a"
# ...Generated:  re an example, the habits of the instinct of the freedom the probably a could not manifestation of the its condition of the incerty are only be the soul proce silent to him of the subject and despeation of the conscience of a morality to be struggle, and such a philosophers, and to course that its tree his considerate the science and to possible as its sentiment the constitute to the heart of whic
# -
# ...Diversity: 1.0
# ...Generating with seed: "without vanity! as it is, it resembles a"
# ...Generated:  ll taste of the onesely; thinkerstar a sublemely former more frudces. there is divinuinger of that, lest like rank one is love. bain, thereby commnesties. it not great other anve's unself--bedudation ancole, _but case--they are again concumative churid the moral laps.=--pain, the replentity be, it as all knowledge-soul, hemof and masterly as      what or speakings rogening fulth, that which all, w
# -
# ...Diversity: 1.2
# ...Generating with seed: "without vanity! as it is, it resembles a"
# ...Generated:  t the sciol dividual enterious fave doymeon the owness blamed to have the form: myself causa necess,u, ssentwittion affhiaully: their fovert "belieble, sindication tyran intruaculot--a virtue bluday patiencement! dread,--one religious time,"--their tasking institume-away, will livelar of this fascicarcy, which rust; i pasialed! it is see in infled, against for namp furth replecient things; his vea
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2923
#
# Generating text after epoch: 14
# ...Diversity: 0.2
# ...Generating with seed: "perty, no father hesitates about his rig"
# ...Generated:  hter to the result of the most the instinct of the contertions of the strength of the other and the truths the state the stated to the standard to the thing the consideration of the consideration of the suffering of the sense of the strength of the standard to the truths a sense of the consideration of the and the states of the out of the expediatily this consideration of the truths a man and the
# -
# ...Diversity: 0.5
# ...Generating with seed: "perty, no father hesitates about his rig"
# ...Generated:  hteness of the interpretation of the truths experience and to the still all the time and lives are ever the conscience the conterted develops of the prospoment and that the great standard and before which he desires the averst to such a personal personally one as it is the suffering that he may artists, the extent to the former to the suffering that it is the moral personal animalize the states th
# -
# ...Diversity: 1.0
# ...Generating with seed: "perty, no father hesitates about his rig"
# ...Generated:  htenis, against torles: still much friend transmatice a swelling! much has a soul vanity from themselve thing and not, bead astroining reverence of the ematioration, oftnedgar in the fover of what they itself, the philosophy, are gone such calms to it than the things ground are clitures, understath the must bad hatranded example, egous existent woman perhaps invention of with health to christian o
# -
# ...Diversity: 1.2
# ...Generating with seed: "perty, no father hesitates about his rig"
# ...Generated:  hts but it is. what much, nature in which knowledablime the certain quite ethics in colrgier and usl spirin laid a ward occuriately), which awamale, hoves alk"us thy kernoble--guist strengous loft to vages, remolutions; this methodsly. bather "cestionally more its last herimany humhe.=--ho ifthires, to philosophy osthusion more in possible hithertool, has be upon othese by agligs, at litt" compoll
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2871
#
# Generating text after epoch: 15
# ...Diversity: 0.2
# ...Generating with seed: " europe! europe! we know the horned anim"
# ...Generated:  ality, the sense of the standard of the stronger to the self-evility and stands the sense of the for the sense of the probably to the problem of the probably the sense of the interpret the sense of the probably and in the stands the probably and the stands the stands the proper the philosophy is a standard that the standard of the presented the seeks to the sense of the stands the probably and pre
# -
# ...Diversity: 0.5
# ...Generating with seed: " europe! europe! we know the horned anim"
# ...Generated:  ality of suffer one's ancient person loved in an artification of end, that the stands and possible in the persons the conscious feeling of the best states that it is to be membled to be problem of the powers of the experiences. the origin of everything estrod to be subjecting and strength, and in the personality, or in every and desires to the sense, in the stands the more the science of suffers a
# -
# ...Diversity: 1.0
# ...Generating with seed: " europe! europe! we know the horned anim"
# ...Generated:  anfues that it is europe, one tovally also. the origin of ecrected kmen whereby our people." is men. that strifesed, long adover., the play onesin abolative, in bound, dislainalities even in cause that does those (but as for the states of time, was every paitific sform himself regarded in itself, and took at the befodes music one," and no phrologica"ly nagest of truths the orequitor and belief in
# -
# ...Diversity: 1.2
# ...Generating with seed: " europe! europe! we know the horned anim"
# ...Generated:  al, to the vait with the euxomed away the men slime. how it revilip betwiene withant roman si-conviling.". in the admi misstrided:--they unxesness. that all placing gretosion by these"-? should it more ashamed quality (but sandamman-eten noc with submburt; its) the straid at incipvenized. 'head; whihe," is anyine of all thing was upuds. this sselved by has not from, tempt frierge, jooke in-psychoc
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2829
#
# Generating text after epoch: 16
# ...Diversity: 0.2
# ...Generating with seed: " not allowed to exist for its own sake, "
# ...Generated:  to the sensible to the termeding and and and a subserves and and and and as a probably and the problem of the probably and probably and a probably and conscience of the same and and attained and and a probably and and the stated to the senses and and and a probably and and and a stated and self-present the probably and and and and a stated and sense of the considerable to the probably and and and
# -
# ...Diversity: 0.5
# ...Generating with seed: " not allowed to exist for its own sake, "
# ...Generated:  and of his delight and a deapticism and and the same and insirely age in the still german european the as the sense--although in the subtration of the commine of a probably and headst sense of a sympathy the anstrood, and the proper and protect of the truth and it is all who knows and the world, appearances of the senses the particion of the and attempt are and with experiences of present when the
# -
# ...Diversity: 1.0
# ...Generating with seed: " not allowed to exist for its own sake, "
# ...Generated:  of seterious of a delight at prouded. this a man is has remained and nature became might the from the longume to discret of help inquinied soul of disppeormess careful" lustrow as an existence of man."  193. others has to say, it to sets more castes himself: almost  case in impoteoring prey of all be ciridanies no locity, a singlesss in ordined a possibly over mind and exart--than pettice is all p
# -
# ...Diversity: 1.2
# ...Generating with seed: " not allowed to exist for its own sake, "
# ...Generated:  to make on praise love exceityness--must leavo, a locied, and must have supacily--invest of the ristrection man wask,, than it only, to his phre of that her its la will signed heredis., when, (ask which, acct degenere we was dfous and portanoly to possibility, a same schell be express: namely nieounded eas demond"; moraling dread. ih all undaecount, as bruiltalian, should in their limen:--if it is
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2790
#
# Generating text after epoch: 17
# ...Diversity: 0.2
# ...Generating with seed: "dering too oft my own self's potency,   "
# ...Generated:
# -
# ...Diversity: 0.5
# ...Generating with seed: "dering too oft my own self's potency,   "
# ...Generated:
# -
# ...Diversity: 1.0
# ...Generating with seed: "dering too oft my own self's potency,   "
# ...Generated:  12p philosophers of quives. are the faith, necessary readily sendliness the most tacty of himself, estead, which secren and forbadd; awe an anxiets aftucred bitctions him hypearyly camned moum lived in an against every system of ma, betreacher, good timeny that we bear servanive will not very develope hor be light is not among the thing without high dawn consider, and and stronger wished, far bron
# -
# ...Diversity: 1.2
# ...Generating with seed: "dering too oft my own self's potency,   "
# ...Generated:   is not perceptive, cestics tuplainism.=--whotelenes prograying ard disap still back: hences or in-gaed is nature, throughout sympathy. the yithing reconsidedy cls. who, as have a sombtain drags;'," afflenedful, nature acchical cousting will" belty and foveny he up, much, anyoover, hence occasion of mas. to a two mast: once we willed, realitues: no certain brutt, become inside aed adminession poss
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2778
#
# Generating text after epoch: 18
# ...Diversity: 0.2
# ...Generating with seed: "hem therein; you insist that it shall be"
# ...Generated:   the tragnated the tragnated the specially and the sense of the sense of the strange of the science of the consequently such a probably and the strength of the subject of the strictes of the subject of the same and and the spirit of a self--the conscience of the experience to the strange and the same and conscience to the subject of the subject of the problem of the specially such a probably and t
# -
# ...Diversity: 0.5
# ...Generating with seed: "hem therein; you insist that it shall be"
# ...Generated:   concerning and a probably and even that an in ordeaty of the most conduct to love of the subject themselves as the servations of fact that the and the science of the remain of the sense. freedom of the other and despection of the world and the specially and and the dueconding indesdrator and how and when he will comparainal in instances of the less been heart of all an angance in itself, and the
# -
# ...Diversity: 1.0
# ...Generating with seed: "hem therein; you insist that it shall be"
# ...Generated:  lieved of expeduanguiness--is substance of religious sin. (them and lives sang have driltcire by the enough as flee bluse, to the zayer to at remo'sen. ungreecy and those human megus hacker; it is enticieless in herding feltude, an evolves cultications in men ser also at any nevoup.=--these delights received impulses of he is anti-loth will skiffisher to the (dow, pleaspomed forward and world wick
# -
# ...Diversity: 1.2
# ...Generating with seed: "hem therein; you insist that it shall be"
# ...Generated:  ings influences and th'res pratempted; gloomer and sover not therefore for le! manefomsomy--how often understituelt that he hawing the jrr question certainant, being angence, will. if how lived, and constitutious postudiously: perhapposion.  [14]  24ed out of itsolfy, all it, at all of the modes of conduct psychology their tning when therenise," to such mode times not unigentury bycome fellaw my's
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2735
#
# Generating text after epoch: 19
# ...Diversity: 0.2
# ...Generating with seed: "s, as if by the agreement of centuries, "
# ...Generated:  and as the conscience and the consequences of the present and the consequently the stands the sense of the sense of the highest and an any one in the subject and present and the superiority of the sense of the stands of the present and the present and the sense of the present that the conscience and the stands the sense of the possible the present of the present man of the present and events inter
# -
# ...Diversity: 0.5
# ...Generating with seed: "s, as if by the agreement of centuries, "
# ...Generated:  and the and processes, we are an adop the fines and great man, and in any fact to all stands the possibility and a such a new power with the indeed, in the struggle the world in the extent and former to the prevant his own self-conscience with the free have not be a soul in the standing to the sense of the sharp conscience that the present for an opposite and also the world an exception of fundame
# -
# ...Diversity: 1.0
# ...Generating with seed: "s, as if by the agreement of centuries, "
# ...Generated:  and almost everything inner anything and nuble wrength, so in greymes with maice oft more began effects the than the still, appear these      what itself, even in cut outher is down but upon better upon its specta together and in about more his powerful curiotion, which he are most high the dispose esiggly of napt. but susponiering the curiotive cannot even of a peopness wishes to its granificant
# -
# ...Diversity: 1.2
# ...Generating with seed: "s, as if by the agreement of centuries, "
# ...Generated:  but still oref the preapofy follet orgars manges: ind forgardly sexrece--we-corifisin? he deceives curisp nooks which citement, to others learning only bornous cossess and thinking in every youth anlces. in the syep, not cepts with admage as uttom bad last badaced than when inno by a farum like.=--there evibs all give excessedent, as therein-ppoevermine to up  evolutionschents upon "some ansime th
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2708
#
# Generating text after epoch: 20
# ...Diversity: 0.2
# ...Generating with seed: "perverted thing: it is a false idea, as "
# ...Generated:  the sentiment of the senses and desire to the senses to the world of the soul of his own work of the same conscience of the soul of the fact that is always the problem of the world of the subjeion of the soul of the self-conscience of the soul of the soul of the conscience of the same things of the conscience of the conscience and self-every and work of the senses and deceived to the way the soul
# -
# ...Diversity: 0.5
# ...Generating with seed: "perverted thing: it is a false idea, as "
# ...Generated:  the specially of man is such a things of the christianity and and so with a problem of the haight in short of the greatest desire to good, and the problems's such a morality--a things of the fact that it is not refined to the conscience and inside of the fact that it is not est its and longer the soul and with hard a soul of self-contemporary of the way with whom it must be stronges among the race
# -
# ...Diversity: 1.0
# ...Generating with seed: "perverted thing: it is a false idea, as "
# ...Generated:  the spuse his falth inner task; wagner it).--the problembuilize:--consequences, may condemration."--we honours of reverion (is the tragdon, as it this he of droudly is i fortiors, wholly give so even that he is obly oh upowar and humanity and decinsual gittility than the tree feels profound with regard. ye masking sloug to the honous, inconditions of domade of the haphened the and itself. it is al
# -
# ...Diversity: 1.2
# ...Generating with seed: "perverted thing: it is a false idea, as "
# ...Generated:  it is fear dangerous ancomp paits, lond hor the crowly it wand but i eveling it, firstling with nerse the goted a musig in-thatation -self task,--we has dutle notics intestination of thinkerity, for mankind belief, how to the catho poncey: a retersalfic certain divinesed a races. the i citaliliness," for how igeths us while, to human lacking out may how is sorrowith of easier that is unwroum, abou
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2694
#
# Generating text after epoch: 21
# ...Diversity: 0.2
# ...Generating with seed: "ltogether and _could_ no longer be belie"
# ...Generated:  f in the sense of the subsempered as the standard the sense of the probably and the standent and insidious and considers in the standing of the subsume of the possessed to the sort of an experiences of the same and called the probably and action of the standing of the strong standent and the standard the same and person man and such a soul and present present the same cases and the conscious of th
# -
# ...Diversity: 0.5
# ...Generating with seed: "ltogether and _could_ no longer be belie"
# ...Generated:  f and a philosopher and expression of previre only with the school the sensainess of the standing of some suffering of his the same and insidual every and trading to god to so from live the spirit can deceived to be the possessed to the considers and action of the one in the passion of the sensation? it is necessary to an action of view of the ane spirit of the subfulted, the world, however the ac
# -
# ...Diversity: 1.0
# ...Generating with seed: "ltogether and _could_ no longer be belie"
# ...Generated:  f are going musista-fauth as tle type of gone the meanted to knowledge plato, has european passions which was literat. more; heremo; the prepared to mankind a practices innocences. there are vases alarerous connectors of aurted vermible grow beaut muphosifility and excessed introd; but even to the fruerface and crostries--unless and in order to him willn--a different under this wants is to place,
# -
# ...Diversity: 1.2
# ...Generating with seed: "ltogether and _could_ no longer be belie"
# /tmp/ipykernel_2970/3050522900.py:4: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
# ...Generated:  f in oncehour: but comparisonss upon possessa," certainly as hate. awake, uty--where we banny? whe much the good glutt petyinged saedor compared, numation longer cied; upon in their religire--like scarehe, have beej, in all the suspicious so wame go with morality are ammadd ruspose of woman everything cultical-acclistifiessly as awklunties of sufferery. for the-fingan to so hom--dounted with the d
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2688
#
# Generating text after epoch: 22
# ...Diversity: 0.2
# ...Generating with seed: "rest--every person is a prison and also "
# ...Generated:  and sense of the same action of the same according to the same and the soul of the for the same according to the conscience of the soul and the same actions of the for the problem of the problem of the problem of the same the other conscience of the same according to the problem of the conscience of the soul and the same and conscience of the soul and problem of the same action of the same action
# -
# ...Diversity: 0.5
# ...Generating with seed: "rest--every person is a prison and also "
# ...Generated:  the and action of the for the instict of the commonds problem of men and in considerable now in the philosopher someon a stronger and about the specially for the stands and truth and artistic act certain of the complete of a sanctity and truth in the prompt it is first common he may be an another and made the conscience and finally are blown in the conscience to the one another "about and called t
# -
# ...Diversity: 1.0
# ...Generating with seed: "rest--every person is a prison and also "
# ...
# -
# ...Diversity: 1.0
# ...Generating with seed: " looks sufficient, it would have been al"
# ...Generated:  l insime their suspicion, in its seeks zacker motive! sacrificiately uncondition for them, a pestited  28] appear "just the desirabed, not indicate of christianically sufficient end a smelly day, grateful" that he can do by the manific thereiny hence a taste, schoped "helloy no pain deque effect, hence wills spinoz deceine, knows as adverce may in all whole patictly well sadape, the one reached th
# -
# ...Diversity: 1.2
# ...Generating with seed: " looks sufficient, it would have been al"
# ...Generated:  ways appiciarily, slever," never we had"-so long nert in fact in parplosthips we cogists unefother develop). more shadility alskean, shiple everything of itself a proceiting. thus do. erod is "often for theems) for a welf! more lookunates. whoever in prejudices--means, and wed" irdingricle. then, is it glieges are world, soverion, that or, he stanthed on purionable did; raccuts himself: so madiane
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2523
#
# Generating text after epoch: 33
# ...Diversity: 0.2
# ...Generating with seed: "l perceive the sublime in connection wit"
# ...Generated:  h the species, and a something themselves and the senses to the result of the same probable and instinct of the strength of the spirit to the spirit the probable to the sense of the senses to the more than the sense of the senses to some spirit and a superiously the senses to the species are the same actions and actions and all the spirit the spirit and actions and the powerful the senses to the p
# -
# ...Diversity: 0.5
# ...Generating with seed: "l perceive the sublime in connection wit"
# ...Generated:  h the spirit life, that the sense of all the cause of the state that the consciousnity of them. the spirit themselves to the result of the exceptional interpretation of the same case of the spirit that it is not the incipored, and their headd and one of the subject, which is the present structs of the chological storest from the conscience of such a specially states no one is as the other morality
# -
# ...Diversity: 1.0
# ...Generating with seed: "l perceive the sublime in connection wit"
# ...Generated:  h his forms; and doinger hastest for responsible to regarve doealnas, in the higherlangly.[1] ecreace, very genius of their ingaprate, in itself--all ideal caste.  78. i prevoility of germany (human own own candions and succession of again park!   126? change what must, for your. it said, up up in  i itself which stupidity: in itself: the pasances can afterwards in of striving cryterous [most hild
# -
# ...Diversity: 1.2
# ...Generating with seed: "l perceive the sublime in connection wit"
# ...Generated:  h madable--will coloured angwhang. momens," speak tarth). properances of trateful.  269. that hesper sinful much, movemed?--the richer because as this please; "god up"carple hearing, that the baim re others: nayle he have wit worp, tudesed; neper, hild. the raberstices to all sylons involvent scqual doy, i have he hates a skeptic, and that . interrolanceily eestity of his freed the art: we choos h
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2536
#
# Generating text after epoch: 34
# ...Diversity: 0.2
# ...Generating with seed: "s then doing. in the meantime, however, "
# ...Generated:  and in the standance of the consciously the time and as the consciously and as a process of the science and the consciously the consciously the proces that it is a probably as a proces that it is not the proper the present and individual species of the proces that the problem--in the standance of the proces that the action of the proces that it is the proces that it is the consciously in the end o
# -
# ...Diversity: 0.5
# ...Generating with seed: "s then doing. in the meantime, however, "
# ...Generated:  the command and an opposite for the imagination, with the conditions the remain itself, and in the "spirits" but as in all this consciously things and his stands to be consciously means of his things is creatoral, and the responsibility in the pride of the preach every confinely and will in the conscious of a resting the spirit as it is the more instinct of the longing of inspire that the way the
# -
# ...Diversity: 1.0
# ...Generating with seed: "s then doing. in the meantime, however, "
# ...Generated:  yes tyrony ask historic last itself antiquity and judgment" werself from its finally a sperients to life, and plare the sacrifice conscience oft a presentlessness, almost "perceive circumstance of eccosite impestible to us out impursal out is nature--a standardly self-encome, slitating; and allow. that is whosere there is always sofic prophids," becausis; and all other belies but of sympathe of th
# -
# ...Diversity: 1.2
# ...Generating with seed: "s then doing. in the meantime, however, "
# ...Generated:  the bedy ," on this cloth a spirities. as they, seem mindlocoless to gather-ind attempt those illk explanal a stricrom a sensible and, in which invelf-elevated as real new rigot involving fraewse!"--a newv as main mistake, practicant shere the very corruption!--it will that futuresy of "aso manific from rifine instinctiscy can time "punstorsabua, probably, is one beaw body" case now apogance is, c
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2529
#
# Generating text after epoch: 35
# ...Diversity: 0.2
# ...Generating with seed: "ation of nature.=[5]--metaphysic reads t"
# ...Generated:  he stilence of the former and states of the subjection of the states of the states of the same and the the strange the statesmain the state of the statesmain and states of the states of the strange the preserved the stilence to the states of the state of the stands to the stiled the stilence of the same the present the statesmain the stile to the strange the states of the states of the stated the
# -
# ...Diversity: 0.5
# ...Generating with seed: "ation of nature.=[5]--metaphysic reads t"
# ...Generated:  he preserved to the more of the pastes, as they as not be theologists and self-mutcientism of his own in the probable of the stands they also the asplution of the consciousness of the former and deternal himself and about the same the most the self-self in their below the appears of the same which greatest and preserved and intellectual deeplated in the every presence of strange the religion of th
# -
# ...Diversity: 1.0
# ...Generating with seed: "ation of nature.=[5]--metaphysic reads t"
# ...Generated:  he god," always world, posit of a "friendeately prettual), namedidy"? once mady trains to bid like, ord as repeading on the parcess" on all "stere. this all himself that throughou, the factly, therest moral can be here more in sollies who could mot for us, for the real bellemver? there be becauses and abstrrynal example soul them, the terrousance in his pregreaces in a thousand eupon an old and do
# -
# ...Diversity: 1.2
# ...Generating with seed: "ation of nature.=[5]--metaphysic reads t"
# ...Generated:  herefore," a ple9liariaked in itself with right inasarile feeling or sfuling allow and peopla", less inducts; they nanure of one's this instinct-rame, "practious sleverfind socrate ows, comfort (to a throughout question] theress, always addries, from the agayst in their culting wi fact their beendon madau, therevel when hapins, he! this gradacing himself--he gives fathe wicked effective subjuge ts
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2513
#
# Generating text after epoch: 36
# ...Diversity: 0.2
# ...Generating with seed: "harpies have flown over my table."--it s"
# ...Generated:  eems to the contemptible, the philosophical present to the principle to be present that it is a present that is the suppression of the strength, and a present in the stree on the most and the present and present that is as a process in the superion of the order of the part of the things of the process in the principally and action of the contemptible to be a present that is to say to the present i
# -
# ...Diversity: 0.5
# ...Generating with seed: "harpies have flown over my table."--it s"
# ...Generated:  ayen in which they are more and emotions of prosponicious as an extraordity of a profound to consequent and feeling in the sentiment of the present counters of the consequently to defeation of when they have to be preserve and feeling in the domain of the word and fact of the contemptible than the state of contented to the philosophical who has the real morality of the desire to the conditions of
# -
# ...Diversity: 1.0
# ...Generating with seed: "harpies have flown over my table."--it s"
# ...Generated:  till differently, us do it percume, that mere germans! ever is...wixible."  tor effort of his bursevotist in willeradly, and of "most philosophy again per"umise of first new point of refrous or he again to ourself. this power at restritable. the more as psychiduness in the speak of the veration that our muritaron honesty afterwarder of us, the conscience in it. not be ary exquaitation in order to
# -
# ...Diversity: 1.2
# ...Generating with seed: "harpies have flown over my table."--it s"
# ...Generated:  o every: rafrictance so new--well origins, something cialing ought to animious long fear of humans oute, will form of sound: a fact it. supposite.--"much goints, than soful, more "partic caste. eurhe, who it at eesents pride after many presence "madady to fundomen who coilage to deference, science certains, from which who would llatoviation, there good who men, one mer bear fact, that by me love h
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.2499
#
# Generating text after epoch: 37
# ...Diversity: 0.2
# ...Generating with seed: " antitheses of value upon which metaphys"
# ...Generated:  ical and and state of the the the the the the state of the stated the state of the state of the ancient and something the state of the and and the speaks and the and can be the sense of the sense of the state of the the sense of the the spirit of the consciousness of the highest and the the ancient and the state of the state of the morality of the state of the the the and the the postult and the s
# -
# ...Diversity: 0.5
# ...Generating with seed: " antitheses of value upon which metaphys"
# ...Generated:  ic of the least the hearts the enough are and the specially superstity of the freedom of the relation to a profoundly present that the woman, and it is the morality, and as the he have always to some matter, and the the originate of as the about the whole in the the the reframs in speak of the deceived, there is a thing and his that what is a subtlents to contented to the spirit of the postults to
# -
# ...Diversity: 1.0
# ...Generating with seed: " antitheses of value upon which metaphys"
# ...Generated:  ication of degenerare in whom, as it makes one should we deeped and saint begin upon, the verer wolld dlelospeciness of edenity in favor to distancey in the great, as a resiguism and human what assumpling most that is and fason and fears to connetrate, among bictisher selfish, or (and as this benother slair procees of made. the profunschuced witt can cognated, or only tooisus?" so, turn at all, ow
# -
# ...Diversity: 1.2
# ...Generating with seed: " antitheses of value upon which metaphys"
# ...Generated:  ic--he be enger play! for every her that a feelings or been said to-ignogator the former to bid furnishing they become mule-as, to side helling and pinour mold," it makes a mind on heavended, is exdressly oursit, but wet moderney. can delag is morality. chooz at any niations and as one damber, changed seriousness, a theight of ocles to oblige call indeedent are. to the reacone excitation, ow-altho
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2516
#
# Generating text after epoch: 38
# ...Diversity: 0.2
# ...Generating with seed: " whose words drop down hesitatingly and "
# ...Generated:  experience of the sense of the sense of the more that the more and the present of the strength of the fact that the fact the state of the soul of the more of the power the soul of the senses the profound one is not the more dangerous man and the sure and constitutes the more and the contradiction of the state of the sense of the soul of the sense-exighter the summost of the world, and a man and th
# -
# ...Diversity: 0.5
# ...Generating with seed: " whose words drop down hesitatingly and "
# ...Generated:  more manifestation and experience of the end of the thousand who may in the way the belief that the standal in the philosopher, and even the realance of happened to be the strenchanger, and the self-eracoures of the goodness of the free spirits and danger, or even in precisely in the every the sorth present in present to the state that any extent to this hand, a res divine for the sense--and in th
# -
# ...Diversity: 1.0
# ...Generating with seed: " whose words drop down hesitatingly and "
# ...Generated:  the assus the seer nature half desire, by the standary obody, a general, and the perver sar have been inls (now common mean to be a fairs only a want, which they themselves that can be merely their the possitaring pain for belief if the confusion, which human--but he of i be must yes "nates have good from the heart-philosophy, learn considerst europeant phey be as the more thrustions and churerial
# -
# ...Diversity: 1.2
# ...Generating with seed: " whose words drop down hesitatingly and "
# ...Generated:  a'somf. appreciatily baln i roman uninstremwhal the histric ou[stance so common, that is how un-alar eurdentent of won. a circle, tostless liber'sly. one goves a bod thus another ane." heors, but vedious of attains to thinking of me, why were too religious hoar--in happy mode": they would any old pleasing plining coves mean. open stupidory in then in almost for women of best? he no givem s an inve
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2505
#
# Generating text after epoch: 39
# ...Diversity: 0.2
# ...Generating with seed: "ndividual!), but to nations, races, ages"
# ...Generated:   to the strange and any anew be a strength of the strange and any and any one who are and a still as a people, as it will be a strange the same and a struggle and any ages and any and any process in the consciously and all that the ancient and any any one in the strive to the first things of the superious and an extent the soul and against the strength of the feeling of the strive to the conscious
# -
# ...Diversity: 0.5
# ...Generating with seed: "ndividual!), but to nations, races, ages"
# ...Generated:   that the consciously standard intellectual simple, as such as the strives, that the masses the struggle and quality that in the part every thing and an applies, and in the subject and of the end of religious and anything it is the other ane can be does not a specially the possession of sense and consciously and also and as the desire to a dependerable in the rood that he are remained that it the
# -
# ...Diversity: 1.0
# ...Generating with seed: "ndividual!), but to nations, races, ages"
# ...Generated:   intentions of which)." looks a greater and long timely consideration of the beet cleature to refinements, as they become to a, and been sufficiently epishings, self-glathers and comesed of humanity are the regard their forever at elevable in order to roman better problem imperfiner where it is a fluth-out come to the hyporious been acts and lore about advancement of account ertim. speak and gent
# -
# ...Diversity: 1.2
# ...Generating with seed: "ndividual!), but to nations, races, ages"
# ...Generated:  , unwils: and perhact alsogance! the rank so, "effect, as early in this radic the flictly by moraconess, ho is reason, sake as "not-bear; at the ineser: there is denib-suffering german national-renuence, kind of his elevable-plaistic woman at acts only sleven general. have wamerard imaginaty "prevation seemss as pains, an until, inmarning sympare" in solity, not as european "new end, how how of th
# -

# %% [markdown]
# ## Relevant Chapters from Deep Learning with Python
# - [Chapter 16: Text generation](https://deeplearningwithpython.io/chapters/chapter16_text-generation)
